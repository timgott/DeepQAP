# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.use("pgf")

# %%
plt.plot([1,9,3,4])
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f154ea3d310> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/drlqap-8wMDSQ50-py3.9/lib/python3.9/site-packages/matplotlib/backends/backend_pgf.py:283, in LatexManager.__init__(self)
#     282 try:
# --> 283     latex = subprocess.Popen(
#     284         [self.texcommand, "-halt-on-error"],
#     285         stdin=subprocess.PIPE, stdout=subprocess.PIPE,
#     286         encoding="utf-8", cwd=self.tmpdir)
#     287 except FileNotFoundError as err:
#
# ...
